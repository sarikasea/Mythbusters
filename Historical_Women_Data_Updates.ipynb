# %% [markdown]
# <a href="https://colab.research.google.com/github/sarikasea/Mythbusters/blob/main/Historical_Women_Data_Updates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread gspread_dataframe
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials

from gspread_dataframe import get_as_dataframe
from google.colab import auth
auth.authenticate_user()
import gspread

# %%
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# %%
sheet = gc.open('Historical Women').worksheet('transformations')
dftrans = get_as_dataframe(sheet)

dftrans
# Out:
#                          Name         Era  Country       Region  \
# 0               Elizabeth Fry  18-19th c.  England       Europe
# 1            Savitribai Phule     19th c.    India  Asia-Modern
# 2               Amrita Pritam     20th c.    India  Asia-Modern
# 3               Bachendri Pal  20-21st c.    India  Asia-Modern
# 4            Manushi Chhillar     21st c.    India  Asia-Modern
# ..                        ...         ...      ...          ...
# 334              Simone Biles     21st c.      USA     Americas
# 335               Simone Veil     20th c.   France       Europe
# 336  Susan La Flesche Picotte  19-20th c.      USA     Americas
# 337             Sylvia Rivera     20th c.      USA     Americas
# 338           Urraca of León     12th c.    Spain       Europe
#
#                                   Love Life  \
# 0                           Married, Quaker
# 1               Married, supportive husband
# 2                    Multiple relationships
# ...

# %%
sheet = gc.open('Historical Women').worksheet('forconcat')
forconcat = get_as_dataframe(sheet)

forconcat
# Out:
#                         Name  Date of Birth Date of Death         Ethnicity  \
# 0           Savitribai Phule     3 Jan 1831   10 Mar 1897     Mahar (Dalit)
# 1              Amrita Pritam    31 Aug 1919   31 Oct 2005           Punjabi
# 2              Bachendri Pal    24 May 1954        Living          Garhwali
# 3           Manushi Chhillar    14 May 1997        Living          Haryanvi
# 4              Fathima Beevi    30 Apr 1927        Living      Tamil Muslim
# 5             Aruna Asaf Ali    16 Jul 1909   29 Jul 1996           Bengali
# 6             Pratibha Patil    19 Dec 1934        Living           Marathi
# 7          Durgabai Deshmukh    15 Jul 1909    9 May 1981            Telugu
# 8              Gita Gopinath     8 Dec 1971        Living          Malayali
# 9                 Kiran Bedi    9 June 1949        Living           Punjabi
# 10          Rani Lakshmi Bai  November 1828  18 June 1858         Kshatriya
# ...

# %%
# Out:
#                          Name           Era       Country        Region  \
# 0                 Absh Khatun       13th c.        Persia          Asia
# 1               Ada Blackjack       20th c.  Inuit/Canada      Americas
# 2                Aisha Yesufu       21st c.       Nigeria        Africa
# 3    Alexandria Ocasio-Cortez       21st c.           USA      Americas
# 4               Alice Milliat       20th c.        France        Europe
# ..                        ...           ...           ...           ...
# 334             Yaa Asantewaa  19th-20th c.         Ghana        Africa
# 335                  Yennenga       12th c.  Burkina Faso        Africa
# 336               Yukiko Ueno    20-21st c.         Japan   Asia-Modern
# 337             Zara Mohammed       21st c.            UK        Europe
# 338                   Zenobia        3rd c.       Palmyra  Asia-Ancient
#
#                              Love Life  \
# 0             Married royal, alliances
# ...

# %%
# Out:
#                          Name          Era             Country       Region  \
# 7               Amrita Pritam      20th c.               India  Asia-Modern
# 9    Anandibai Gopalrao Joshi      19th c.               India  Asia-Modern
# 10           Anasuya Sarabhai   19-20th c.               India  Asia-Modern
# 28             Aruna Asaf Ali      20th c.               India  Asia-Modern
# 29     Arundhati Bhattacharya      21st c.               India         Asia
# 30              Arundhati Roy   20-21st c.               India  Asia-Modern
# 33              Bachendri Pal   20-21st c.               India  Asia-Modern
# 73                   Draupadi  Ancient era  Mythological India    Asia-Myth
# 74             Draupadi Murmu      21st c.               India  Asia-Modern
# 75          Durgabai Deshmukh      20th c.               India  Asia-Modern
# 78                Ekta Kapoor   20-21st c.               India  Asia-Modern
# ...

# %%
from gspread_dataframe import set_with_dataframe

# Open the Google Sheet and the target worksheet
sheet = gc.open('Historical Women').worksheet('Cleaned Data')

# Write the DataFrame to the worksheet
set_with_dataframe(sheet, merged_df)
